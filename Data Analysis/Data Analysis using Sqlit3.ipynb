# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import sqlite3

# %%
data = sqlite3.connect("database.sqlite")
cur = data.cursor()

# %%
cur.execute("select * from player")
obj = cur.fetchall()
obj
# Out:
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154),
#  (6, 27316, 'Aaron Hunt', 158138, '1986-09-04 00:00:00', 182.88, 161),
#  (7, 564793, 'Aaron Kuhl', 221280, '1996-01-30 00:00:00', 172.72, 146),
#  (8, 30895, 'Aaron Lennon', 152747, '1987-04-16 00:00:00', 165.1, 139),
#  (9, 528212, 'Aaron Lennox', 206592, '1993-02-19 00:00:00', 190.5, 181),
#  (10, 101042, 'Aaron Meijers', 188621, '1987-10-28 00:00:00', 175.26, 170),
#  (11, 23889, 'Aaron Mokoena', 47189, '1980-11-25 00:00:00', 182.88, 181),
#  (12, 231592, 'Aaron Mooy', 194958, '1990-09-15 00:00:00', 175.26, 150),
#  (13, 163222, 'Aaron Muirhead', 213568, '1990-08-30 00:00:00', 187.96, 168),
# ...

# %%
df = pd.DataFrame(obj,columns=["sno","id","name","runs","dob","avg","highest"])
df.head()
# Out:
#    sno      id                name    runs                  dob     avg  \
# 0    1  505942  Aaron Appindangoye  218353  1992-02-29 00:00:00  182.88
# 1    2  155782     Aaron Cresswell  189615  1989-12-15 00:00:00  170.18
# 2    3  162549         Aaron Doran  186170  1991-05-13 00:00:00  170.18
# 3    4   30572       Aaron Galindo  140161  1982-05-08 00:00:00  182.88
# 4    5   23780        Aaron Hughes   17725  1979-11-08 00:00:00  182.88
#
#    highest
# 0      187
# 1      146
# 2      163
# 3      198
# 4      154

# %%
df
# Out:
#          sno      id                 name    runs                  dob  \
# 0          1  505942   Aaron Appindangoye  218353  1992-02-29 00:00:00
# 1          2  155782      Aaron Cresswell  189615  1989-12-15 00:00:00
# 2          3  162549          Aaron Doran  186170  1991-05-13 00:00:00
# 3          4   30572        Aaron Galindo  140161  1982-05-08 00:00:00
# 4          5   23780         Aaron Hughes   17725  1979-11-08 00:00:00
# ...      ...     ...                  ...     ...                  ...
# 11055  11071   26357       Zoumana Camara    2488  1979-04-03 00:00:00
# 11056  11072  111182         Zsolt Laczko  164680  1986-12-18 00:00:00
# 11057  11073   36491            Zsolt Low  111191  1979-04-29 00:00:00
# 11058  11074   35506  Zurab Khizanishvili   47058  1981-10-06 00:00:00
# 11059  11075   39902   Zvjezdan Misimovic  102359  1982-06-05 00:00:00
#
#           avg  highest
# 0      182.88      187
# 1      170.18      146
# 2      170.18      163
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sno      11060 non-null  int64
#  1   id       11060 non-null  int64
#  2   name     11060 non-null  object
#  3   runs     11060 non-null  int64
#  4   dob      11060 non-null  object
#  5   avg      11060 non-null  float64
#  6   highest  11060 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 605.0+ KB

# %%
cur.execute("select * from country")
country = cur.fetchall()
country
# Out:
# [(1, 'Belgium'),
#  (1729, 'England'),
#  (4769, 'France'),
#  (7809, 'Germany'),
#  (10257, 'Italy'),
#  (13274, 'Netherlands'),
#  (15722, 'Poland'),
#  (17642, 'Portugal'),
#  (19694, 'Scotland'),
#  (21518, 'Spain'),
#  (24558, 'Switzerland')]

# %%
country = pd.DataFrame(country,columns = ["cour_id","country"])

# %%
country
# Out:
#     cour_id      country
# 0         1      Belgium
# 1      1729      England
# 2      4769       France
# 3      7809      Germany
# 4     10257        Italy
# 5     13274  Netherlands
# 6     15722       Poland
# 7     17642     Portugal
# 8     19694     Scotland
# 9     21518        Spain
# 10    24558  Switzerland

# %%
cur.execute('select name from country')
id = cur.fetchall()
id
# Out:
# [('Belgium',),
#  ('England',),
#  ('France',),
#  ('Germany',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Portugal',),
#  ('Scotland',),
#  ('Spain',),
#  ('Switzerland',)]

# %%
cur.execute("pragma table_info('country')")
info = cur.fetchall()
info
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'name', 'TEXT', 0, None, 0)]

# %%
cur.execute("pragma table_info('player')")
info = cur.fetchall()
info
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'player_api_id', 'INTEGER', 0, None, 0),
#  (2, 'player_name', 'TEXT', 0, None, 0),
#  (3, 'player_fifa_api_id', 'INTEGER', 0, None, 0),
#  (4, 'birthday', 'TEXT', 0, None, 0),
#  (5, 'height', 'INTEGER', 0, None, 0),
#  (6, 'weight', 'INTEGER', 0, None, 0)]

# %%
cur.execute('select * from player where player_name like "Aaron%"')
name = cur.fetchall()
name
# Out:
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154),
#  (6, 27316, 'Aaron Hunt', 158138, '1986-09-04 00:00:00', 182.88, 161),
#  (7, 564793, 'Aaron Kuhl', 221280, '1996-01-30 00:00:00', 172.72, 146),
#  (8, 30895, 'Aaron Lennon', 152747, '1987-04-16 00:00:00', 165.1, 139),
#  (9, 528212, 'Aaron Lennox', 206592, '1993-02-19 00:00:00', 190.5, 181),
#  (10, 101042, 'Aaron Meijers', 188621, '1987-10-28 00:00:00', 175.26, 170),
#  (11, 23889, 'Aaron Mokoena', 47189, '1980-11-25 00:00:00', 182.88, 181),
#  (12, 231592, 'Aaron Mooy', 194958, '1990-09-15 00:00:00', 175.26, 150),
#  (13, 163222, 'Aaron Muirhead', 213568, '1990-08-30 00:00:00', 187.96, 168),
# ...

# %%
cur.execute('select weight from player where player_name like "Aaron%"')
name = cur.fetchall()
name[9]
# Out:
# (170,)

# %%
cur.execute("select count(*) from player")
rows = cur.fetchall()
rows
# Out:
# [(11060,)]

# %%
cur.execute("select player_name from player order by player_api_id desc limit 3")
desc = cur.fetchall()
for i in desc:
    print(i[0])
# Out:
# Alexandre Azevedo
# Rees Greenwood
# Fynn Arkenberg

# %%
cur.execute("select * from player where birthday like '1992%' and weight == 150")
two = cur.fetchall()
two
# Out:
# [(227,
#   199829,
#   'Aiden Chippendale',
#   197939,
#   '1992-05-24 00:00:00',
#   172.72,
#   150),
#  (409, 213500, 'Alex Fernandez', 199247, '1992-10-15 00:00:00', 180.34, 150),
#  (431, 262753, 'Alex Schalk', 203447, '1992-08-07 00:00:00', 170.18, 150),
#  (970, 179411, 'Arnaud Souquet', 193470, '1992-02-12 00:00:00', 177.8, 150),
#  (1738, 242887, 'Christian Atsu', 205601, '1992-01-10 00:00:00', 172.72, 150),
#  (2558, 210126, 'Dennis Appiah', 199191, '1992-06-09 00:00:00', 177.8, 150),
#  (2769,
#   178261,
#   'Dorian Dessoleil',
#   209673,
#   '1992-08-07 00:00:00',
#   182.88,
#   150),
#  (2822, 277827, 'Dylan De Belder', 204619, '1992-04-03 00:00:00', 182.88, 150),
#  (3316,
#   265123,
#   'Fernando Canesin Matos',
#   199651,
#   '1992-02-27 00:00:00',
#   175.26,
#   150),
#  (4163, 207523, 'Hector Quinones', 211499, '1992-03-17 00:00:00', 177.8, 150),
#  (4515, 143793, 'Jack Wilshere', 189461, '1992-01-01 00:00:00', 172.72, 150),
# ...

# %%
cur.execute("pragma table_info('Player_Attributes')")
info = cur.fetchall()
info
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'player_fifa_api_id', 'INTEGER', 0, None, 0),
#  (2, 'player_api_id', 'INTEGER', 0, None, 0),
#  (3, 'date', 'TEXT', 0, None, 0),
#  (4, 'overall_rating', 'INTEGER', 0, None, 0),
#  (5, 'potential', 'INTEGER', 0, None, 0),
#  (6, 'preferred_foot', 'TEXT', 0, None, 0),
#  (7, 'attacking_work_rate', 'TEXT', 0, None, 0),
#  (8, 'defensive_work_rate', 'TEXT', 0, None, 0),
#  (9, 'crossing', 'INTEGER', 0, None, 0),
#  (10, 'finishing', 'INTEGER', 0, None, 0),
#  (11, 'heading_accuracy', 'INTEGER', 0, None, 0),
#  (12, 'short_passing', 'INTEGER', 0, None, 0),
#  (13, 'volleys', 'INTEGER', 0, None, 0),
#  (14, 'dribbling', 'INTEGER', 0, None, 0),
#  (15, 'curve', 'INTEGER', 0, None, 0),
#  (16, 'free_kick_accuracy', 'INTEGER', 0, None, 0),
#  (17, 'long_passing', 'INTEGER', 0, None, 0),
#  (18, 'ball_control', 'INTEGER', 0, None, 0),
#  (19, 'acceleration', 'INTEGER', 0, None, 0),
#  (20, 'sprint_speed', 'INTEGER', 0, None, 0),
# ...

# %%
cur.execute("select count(*) from Player_Attributes")
one = cur.fetchall()
one
# Out:
# [(183978,)]

# %%
cur.execute("select count(*) from Player")
one = cur.fetchall()
one
# Out:
# [(11060,)]

# %%
cur.execute('select overall_rating,player_name from Player_Attributes inner join Player on Player.id = Player_Attributes.id where Player.height > 150')
join = cur.fetchall()
print(len(join))
join
# Out:
# 11060
# [(67, 'Aaron Appindangoye'),
#  (67, 'Aaron Cresswell'),
#  (62, 'Aaron Doran'),
#  (61, 'Aaron Galindo'),
#  (61, 'Aaron Hughes'),
#  (74, 'Aaron Hunt'),
#  (74, 'Aaron Kuhl'),
#  (73, 'Aaron Lennon'),
#  (73, 'Aaron Lennox'),
#  (73, 'Aaron Meijers'),
#  (73, 'Aaron Mokoena'),
#  (74, 'Aaron Mooy'),
#  (73, 'Aaron Muirhead'),
#  (71, 'Aaron Niguez'),
#  (71, 'Aaron Ramsey'),
#  (71, 'Aaron Splaine'),
#  (70, 'Aaron Taylor-Sinclair'),
#  (70, 'Aaron Wilbraham'),
#  (70, 'Aatif Chahechouhe'),
#  (70, 'Abasse Ba'),
#  (70, 'Abdelaziz Barrada'),
#  (70, 'Abdelfettah Boukhriss'),
#  (69, 'Abdelhamid El Kaoutari'),
#  (69, 'Abdelkader Ghezzal'),
#  (69, 'Abdellah Zoubir'),
#  (69, 'Abdelmajid Oulmers'),
#  (69, 'Abdelmalek Cherrad'),
#  (69, 'Abdelmalek El Hasnaoui'),
#  (69, 'Abdelouahed Chakhsi'),
#  (68, 'Abderrazak Jadid'),
#  (65, 'Abdeslam Ouaddou'),
#  (64, 'Abdessalam Benjelloun'),
#  (54, 'Abdou Diallo'),
#  (51, 'Abdou Traore'),
#  (52, 'Abdoul Ba'),
# ...

# %%
data = sqlite3.connect("movie.sqlite")
cursor = data.cursor()

# %%
cursor.execute("pragma table_info('movies')")
movies = cursor.fetchall()
movies
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'original_title', 'VARCHAR', 0, None, 0),
#  (2, 'budget', 'INTEGER', 0, None, 0),
#  (3, 'popularity', 'INTEGER', 0, None, 0),
#  (4, 'release_date', 'TEXT', 0, None, 0),
#  (5, 'revenue', 'INTEGER', 0, None, 0),
#  (6, 'title', 'TEXT', 0, None, 0),
#  (7, 'vote_average', 'REAL', 0, None, 0),
#  (8, 'vote_count', 'INTEGER', 0, None, 0),
#  (9, 'overview', 'TEXT', 0, None, 0),
#  (10, 'tagline', 'TEXT', 0, None, 0),
#  (11, 'uid', 'INTEGER', 0, None, 0),
#  (12, 'director_id', 'INTEGER', 1, '0', 0)]

# %%
cursor.execute("select * from movies")
movies = cursor.fetchall()
movies = pd.DataFrame(movies)
movies.head()
# Out:
#       0                                         1          2    3   \
# 0  43597                                    Avatar  237000000  150
# 1  43598  Pirates of the Caribbean: At World's End  300000000  139
# 2  43599                                   Spectre  245000000  107
# 3  43600                     The Dark Knight Rises  250000000  112
# 4  43601                               John Carter  260000000   43
#
#            4           5                                         6    7   \
# 0  2009-12-10  2787965087                                    Avatar  7.2
# 1  2007-05-19   961000000  Pirates of the Caribbean: At World's End  6.9
# 2  2015-10-26   880674609                                   Spectre  6.3
# 3  2012-07-16  1084939099                     The Dark Knight Rises  7.6
# 4  2012-03-07   284139100                               John Carter  6.1
#
#       8                                                  9   \
# ...

# %%
cursor.execute("select * from directors")
directors = cursor.fetchall()
directors = pd.DataFrame(directors)
directors.head()
# Out:
#                    0     1  2     3          4
# 0      James Cameron  4762  2  2710  Directing
# 1     Gore Verbinski  4763  2  1704  Directing
# 2         Sam Mendes  4764  2    39  Directing
# 3  Christopher Nolan  4765  2   525  Directing
# 4     Andrew Stanton  4766  2     7  Directing

# %%
cursor.execute("pragma table_info('directors')")
movies = cursor.fetchall()
movies
# Out:
# [(0, 'name', 'TEXT', 0, None, 0),
#  (1, 'id', 'INTEGER', 0, None, 1),
#  (2, 'gender', 'INTEGER', 0, None, 0),
#  (3, 'uid', 'INTEGER', 0, None, 0),
#  (4, 'department', 'TEXT', 0, None, 0)]

# %%
cursor.execute('select name from directors inner join movies on directors.id = movies.director_id')
data = cursor.fetchall()
data
# Out:
# [('James Cameron',),
#  ('Gore Verbinski',),
#  ('Sam Mendes',),
#  ('Christopher Nolan',),
#  ('Andrew Stanton',),
#  ('Sam Raimi',),
#  ('Byron Howard',),
#  ('Joss Whedon',),
#  ('David Yates',),
#  ('Zack Snyder',),
#  ('Bryan Singer',),
#  ('Marc Forster',),
#  ('Gore Verbinski',),
#  ('Gore Verbinski',),
#  ('Zack Snyder',),
#  ('Andrew Adamson',),
#  ('Joss Whedon',),
#  ('Rob Marshall',),
#  ('Barry Sonnenfeld',),
#  ('Peter Jackson',),
#  ('Marc Webb',),
#  ('Ridley Scott',),
#  ('Peter Jackson',),
#  ('Chris Weitz',),
#  ('Peter Jackson',),
#  ('James Cameron',),
#  ('Anthony Russo',),
#  ('Peter Berg',),
#  ('Colin Trevorrow',),
#  ('Sam Mendes',),
#  ('Sam Raimi',),
#  ('Shane Black',),
#  ('Tim Burton',),
#  ('Brett Ratner',),
#  ('Dan Scanlon',),
#  ('Michael Bay',),
#  ('Michael Bay',),
#  ('Sam Raimi',),
#  ('Marc Webb',),
#  ('Joseph Kosinski',),
#  ('John Lasseter',),
#  ('Martin Campbell',),
#  ('Lee Unkrich',),
#  ('McG',),
#  ('James Wan',),
# ...

# %%
cursor.execute('select sum(revenue),name from movies inner join directors on movies.director_id = directors.id ')
data = cursor.fetchall()
data
# Out:
# [(395095074714, 'James Cameron')]

# %%
cursor.execute('select * from movies order by revenue desc limit 10')
high = cursor.fetchall()
df = pd.DataFrame(high)
df
# Out:
#       0                           1          2    3           4           5   \
# 0  43597                      Avatar  237000000  150  2009-12-10  2787965087
# 1  43622                     Titanic  200000000  100  1997-11-18  1845034188
# 2  43613                The Avengers  220000000  144  2012-04-25  1519557910
# 3  43625              Jurassic World  150000000  418  2015-06-09  1513528810
# 4  43641                   Furious 7  190000000  102  2015-04-01  1506249360
# 5  43604     Avengers: Age of Ultron  280000000  134  2015-04-22  1405403694
# 6  43721                      Frozen  150000000  165  2013-11-27  1274219009
# 7  43628                  Iron Man 3  200000000   77  2013-04-18  1215439994
# 8  44143                     Minions   74000000  875  2015-06-17  1156730962
# 9  43623  Captain America: Civil War  250000000  198  2016-04-27  1153304495
#
#                            6    7      8   \
# 0                      Avatar  7.2  11800
# ...

# %%
cursor.execute('select * from movies order by vote_average desc limit 1')
high = cursor.fetchall()
pd.DataFrame(high)
# Out:
#       0                 1   2   3           4   5                 6     7   \
# 0  47116  Stiff Upper Lips   0   0  1998-06-12   0  Stiff Upper Lips  10.0
#
#    8                                                  9     10     11    12
# 0   1  Stiff Upper Lips is a broad parody of British ...  None  89861  6332

# %%
x = '''
select distinct(name).count(titles),sum(revenue) from directors inner join movies on movies.director_id = directors.id
'''

# %%
cursor.execute('select name,count(title),sum(revenue) from movies inner join directors where movies.director_id = directors.id group by director_id order by sum(revenue) desc limit 10')
data = cursor.fetchall()
data
# Out:
# [('Steven Spielberg', 27, 9147393164),
#  ('Peter Jackson', 9, 6498642820),
#  ('James Cameron', 7, 5883569439),
#  ('Michael Bay', 12, 5832524638),
#  ('Christopher Nolan', 8, 4227483234),
#  ('Chris Columbus', 11, 3725631503),
#  ('Robert Zemeckis', 13, 3590622002),
#  ('George Lucas', 5, 3339113893),
#  ('Tim Burton', 14, 3337418241),
#  ('Ridley Scott', 16, 3189557997)]

# %%
pd.DataFrame(data,columns=["Name","No. of Movies","Total Revenue"])
# Out:
#                 Name  No. of Movies  Total Revenue
# 0   Steven Spielberg             27     9147393164
# 1      Peter Jackson              9     6498642820
# 2      James Cameron              7     5883569439
# 3        Michael Bay             12     5832524638
# 4  Christopher Nolan              8     4227483234
# 5     Chris Columbus             11     3725631503
# 6    Robert Zemeckis             13     3590622002
# 7       George Lucas              5     3339113893
# 8         Tim Burton             14     3337418241
# 9       Ridley Scott             16     3189557997

# %%
cursor.execute('select name,count(title),sum(revenue) from movies inner join directors where directors.id = movies.director_id group by director_id order by count(title) desc limit 10')
data = cursor.fetchall()
data
# Out:
# [('Steven Spielberg', 27, 9147393164),
#  ('Woody Allen', 21, 669101038),
#  ('Clint Eastwood', 20, 2512058888),
#  ('Martin Scorsese', 20, 1956635998),
#  ('Spike Lee', 16, 340618771),
#  ('Robert Rodriguez', 16, 1109899581),
#  ('Ridley Scott', 16, 3189557997),
#  ('Renny Harlin', 15, 1031500590),
#  ('Steven Soderbergh', 15, 2114864443),
#  ('Oliver Stone', 14, 1278048615)]

# %%
pd.DataFrame(data)
# Out:
#                    0   1           2
# 0   Steven Spielberg  27  9147393164
# 1        Woody Allen  21   669101038
# 2     Clint Eastwood  20  2512058888
# 3    Martin Scorsese  20  1956635998
# 4          Spike Lee  16   340618771
# 5   Robert Rodriguez  16  1109899581
# 6       Ridley Scott  16  3189557997
# 7       Renny Harlin  15  1031500590
# 8  Steven Soderbergh  15  2114864443
# 9       Oliver Stone  14  1278048615

# %%
cursor.execute("pragma table_info('movies')")
movies = cursor.fetchall()
movies
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'original_title', 'VARCHAR', 0, None, 0),
#  (2, 'budget', 'INTEGER', 0, None, 0),
#  (3, 'popularity', 'INTEGER', 0, None, 0),
#  (4, 'release_date', 'TEXT', 0, None, 0),
#  (5, 'revenue', 'INTEGER', 0, None, 0),
#  (6, 'title', 'TEXT', 0, None, 0),
#  (7, 'vote_average', 'REAL', 0, None, 0),
#  (8, 'vote_count', 'INTEGER', 0, None, 0),
#  (9, 'overview', 'TEXT', 0, None, 0),
#  (10, 'tagline', 'TEXT', 0, None, 0),
#  (11, 'uid', 'INTEGER', 0, None, 0),
#  (12, 'director_id', 'INTEGER', 1, '0', 0)]

# %%
cursor.execute('select title,release_date,budget,revenue,popularity,vote_average from movies inner join directors on directors.id = movies.director_id where name = "Steven Spielberg"')
data = cursor.fetchall()
data
# Out:
# [('Indiana Jones and the Kingdom of the Crystal Skull',
#   '2008-05-21',
#   185000000,
#   786636033,
#   75,
#   5.7),
#  ('The BFG', '2016-06-01', 140000000, 183345589, 44, 6.0),
#  ('War of the Worlds', '2005-06-28', 132000000, 591739379, 48, 6.2),
#  ('The Adventures of Tintin', '2011-10-25', 130000000, 371940071, 89, 6.7),
#  ('Minority Report', '2002-06-20', 102000000, 358372926, 65, 7.1),
#  ('A.I. Artificial Intelligence', '2001-06-29', 100000000, 235926552, 34, 6.8),
#  ('The Lost World: Jurassic Park', '1997-05-23', 73000000, 229074524, 2, 6.2),
#  ('The Terminal', '2004-06-17', 60000000, 219417255, 57, 7.0),
#  ('Munich', '2005-12-22', 70000000, 130358911, 29, 6.9),
#  ('Hook', '1991-12-11', 70000000, 300854823, 33, 6.6),
#  ('War Horse', '2011-12-25', 66000000, 177584879, 29, 7.0),
#  ('Saving Private Ryan', '1998-07-24', 70000000, 481840909, 76, 7.9),
#  ('Lincoln', '2012-11-09', 65000000, 275293450, 36, 6.7),
# ...

# %%
pd.DataFrame(data,columns=["Title","Release_date","Budget","Revenue","Popularity","Vote_avg"])
# Out:
#                                                 Title Release_date     Budget  \
# 0   Indiana Jones and the Kingdom of the Crystal S...   2008-05-21  185000000
# 1                                             The BFG   2016-06-01  140000000
# 2                                   War of the Worlds   2005-06-28  132000000
# 3                            The Adventures of Tintin   2011-10-25  130000000
# 4                                     Minority Report   2002-06-20  102000000
# 5                        A.I. Artificial Intelligence   2001-06-29  100000000
# 6                       The Lost World: Jurassic Park   1997-05-23   73000000
# 7                                        The Terminal   2004-06-17   60000000
# 8                                              Munich   2005-12-22   70000000
# 9                                                Hook   1991-12-11   70000000
# 10                                          War Horse   2011-12-25   66000000
# ...
