# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns
import json

# %%
import requests

# %%
data = requests.get("http://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/grades.json")
data
# Out:
# <Response [200]>

# %%
type(data.content)
# Out:
# bytes

# %%
info
# Out:
# <bound method Response.json of <Response [200]>>

# %%
array = []
for i in data:
    array.append(i)

# %%
array
# Out:
# [b'{ "_id" : { "$oid" : "50b59cd75bed76f46522c34e" }, "student_id" : 0, "class_id" : 2, "scores" : [ { "type" : "exam", "score" : 5',
#  b'7.92947112575566 }, { "type" : "quiz", "score" : 21.24542588206755 }, { "type" : "homework", "score" : 68.19567810587429 }, { "t',
#  b'ype" : "homework", "score" : 67.95019716560351 }, { "type" : "homework", "score" : 18.81037253352722 } ] }\n{ "_id" : { "$oid" : ',
#  b'"50b59cd75bed76f46522c34f" }, "student_id" : 0, "class_id" : 28, "scores" : [ { "type" : "exam", "score" : 39.17749400402234 }, ',
#  b'{ "type" : "quiz", "score" : 78.44172815491468 }, { "type" : "homework", "score" : 20.81782269075502 }, { "type" : "homework", "',
#  b'score" : 70.44520452408949 }, { "type" : "homework", "score" : 50.66616327819226 }, { "type" : "homework", "score" : 53.84983118',
#  b'363991 } ] }\n{ "_id" : { "$oid" : "50b59cd75bed76f46522c350" }, "student_id" : 0, "class_id" : 5, "scores" : [ { "type" : "exam"',
# ...

# %%
len(array)
# Out:
# 730

# %%
array[0]
# Out:
# b'{ "_id" : { "$oid" : "50b59cd75bed76f46522c34e" }, "student_id" : 0, "class_id" : 2, "scores" : [ { "type" : "exam", "score" : 5'

# %%
df = pd.read_json("http://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/grades.json",lines = True)
df.head()
# Out:
#                                     _id  student_id  class_id  \
# 0  {'$oid': '50b59cd75bed76f46522c34e'}           0         2
# 1  {'$oid': '50b59cd75bed76f46522c34f'}           0        28
# 2  {'$oid': '50b59cd75bed76f46522c350'}           0         5
# 3  {'$oid': '50b59cd75bed76f46522c351'}           0        16
# 4  {'$oid': '50b59cd75bed76f46522c352'}           0        24
#
#                                               scores
# 0  [{'type': 'exam', 'score': 57.92947112575566},...
# 1  [{'type': 'exam', 'score': 39.17749400402234},...
# 2  [{'type': 'exam', 'score': 88.22950674232497},...
# 3  [{'type': 'exam', 'score': 59.1805667559299}, ...
# 4  [{'type': 'exam', 'score': 4.444435759027499},...

# %%
new = pd.DataFrame()

# %%
ids = [] 
clean = df["_id"]
for i in df['_id']:
    new = re.sub("^{'.* '|'}","",clean[i])
# Out:
# C:\Users\bhuva\AppData\Local\Temp\ipykernel_8828\2686355033.py:4: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   new = re.sub("^{'.* '|'}","",clean[i])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [54], line 4
#       2 clean = df["_id"]
#       3 for i in df['_id']:
# ----> 4     new = re.sub("^{'.* '|'}","",clean[i])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1024, in Series._get_with(self, key)
#    1021         return self.iloc[key]
#    1023 # handle the dup indexing case GH#4246
# ...

# %%
clean[0]
# Out:
# {'$oid': '50b59cd75bed76f46522c34e'}

# %%
new = re.sub("^{'.* '|'}","",str(clean[23]))
new
# Out:
# '50b59cd75bed76f46522c365'

# %%
array = []
for i in clean:
    array.append(i["$oid"])

# %%
new["id"] = array

# %%
dataframe = pd.DataFrame()

# %%
df.tail()
# Out:
#                                       _id  student_id  class_id  \
# 275  {'$oid': '50b59cd75bed76f46522c461'}          48        10
# 276  {'$oid': '50b59cd75bed76f46522c462'}          48        14
# 277  {'$oid': '50b59cd75bed76f46522c463'}          48         8
# 278  {'$oid': '50b59cd75bed76f46522c464'}          48        15
# 279  {'$oid': '50b59cd75bed76f46522c465'}          49        29
#
#                                                 scores
# 275  [{'type': 'exam', 'score': 19.75901367795435},...
# 276  [{'type': 'exam', 'score': 66.79008851052096},...
# 277  [{'type': 'exam', 'score': 87.50309579619501},...
# 278  [{'type': 'exam', 'score': 17.49112864462374},...
# 279  [{'type': 'exam', 'score': 26.67878234847454},...

# %%
dataframe['ID'] = array
dataframe.head()
# Out:
#                          ID
# 0  50b59cd75bed76f46522c34e
# 1  50b59cd75bed76f46522c34f
# 2  50b59cd75bed76f46522c350
# 3  50b59cd75bed76f46522c351
# 4  50b59cd75bed76f46522c352

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      280 non-null    object
# dtypes: object(1)
# memory usage: 2.3+ KB

# %%
dataframe.
# Out:
#                            ID
# 0    50b59cd75bed76f46522c34e
# 1    50b59cd75bed76f46522c34f
# 2    50b59cd75bed76f46522c350
# 3    50b59cd75bed76f46522c351
# 4    50b59cd75bed76f46522c352
# ..                        ...
# 275  50b59cd75bed76f46522c461
# 276  50b59cd75bed76f46522c462
# 277  50b59cd75bed76f46522c463
# 278  50b59cd75bed76f46522c464
# 279  50b59cd75bed76f46522c465
#
# [280 rows x 1 columns]

# %%
df['_id'] = array

# %%
df['_id'] = df['_id'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      280 non-null    int64
#  1   class_id        280 non-null    int64
#  2   Exam_score      280 non-null    float64
#  3   Homework_score  280 non-null    float64
#  4   Quiz_score      280 non-null    float64
#  5   Id              280 non-null    object
#  6   _id             280 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 15.4+ KB

# %%
clean = df["scores"]
exam = []
quiz = []
homework = []
for i in clean:
    exam.append(round(i[0]['score'],2))
    quiz.append(round(i[1]['score'],2))
    count = 0
    for val in i:
        if val["type"] == "homework":
            count += 1
    sum = 0
    for j in range(2,count):
        sum += i[j]['score']
    homework.append(round(sum/3,2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scores'
#
# ...

# %%
clean[100]
# Out:
# [{'type': 'exam', 'score': 28.44616239797351},
#  {'type': 'quiz', 'score': 61.68253532026511},
#  {'type': 'homework', 'score': 48.70395034065579},
#  {'type': 'homework', 'score': 60.14281257828002},
#  {'type': 'homework', 'score': 67.1876659792913},
#  {'type': 'homework', 'score': 88.01503433639428}]

# %%
(clean[0][2]["score"] + clean[0][3]["score"] + clean[0][4]["score"]) / 3
# Out:
# 51.65208260166833

# %%
clean[0][-1]
# Out:
# {'type': 'homework', 'score': 18.81037253352722}

# %%
clean[0]
# Out:
# [{'type': 'exam', 'score': 57.92947112575566},
#  {'type': 'quiz', 'score': 21.24542588206755},
#  {'type': 'homework', 'score': 68.1956781058743},
#  {'type': 'homework', 'score': 67.95019716560351},
#  {'type': 'homework', 'score': 18.81037253352722}]

# %%
len(homework)
# Out:
# 280

# %%
df['Exam_score'] = exam
df['Homework_score'] = homework
df['Quiz_score'] = quiz

# %%
df
# Out:
#                           _id  student_id  class_id  Exam_score  \
# 0    50b59cd75bed76f46522c34e           0         2       57.93
# 1    50b59cd75bed76f46522c34f           0        28       39.18
# 2    50b59cd75bed76f46522c350           0         5       88.23
# 3    50b59cd75bed76f46522c351           0        16       59.18
# 4    50b59cd75bed76f46522c352           0        24        4.44
# ..                        ...         ...       ...         ...
# 275  50b59cd75bed76f46522c461          48        10       19.76
# 276  50b59cd75bed76f46522c462          48        14       66.79
# 277  50b59cd75bed76f46522c463          48         8       87.50
# 278  50b59cd75bed76f46522c464          48        15       17.49
# 279  50b59cd75bed76f46522c465          49        29       26.68
#
#      Homework_score  Quiz_score
# 0             22.73       21.25
# 1             30.42       78.44
# 2             19.65       79.29
# 3              2.16       47.59
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   _id             280 non-null    object
#  1   student_id      280 non-null    int64
#  2   class_id        280 non-null    int64
#  3   Exam_score      280 non-null    float64
#  4   Homework_score  280 non-null    float64
#  5   Quiz_score      280 non-null    float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
df
# Out:
#      student_id  class_id  Exam_score  Homework_score  Quiz_score  \
# 0             0         2       57.93           22.73       21.25
# 1             0        28       39.18           30.42       78.44
# 2             0         5       88.23           19.65       79.29
# 3             0        16       59.18            2.16       47.59
# 4             0        24        4.44            0.00       28.63
# ..          ...       ...         ...             ...         ...
# 275          48        10       19.76            6.98       88.30
# 276          48        14       66.79            0.00        6.84
# 277          48         8       87.50           45.22       77.95
# 278          48        15       17.49           24.56       26.63
# 279          49        29       26.68            0.00       43.35
#
#                            Id
# 0    50b59cd75bed76f46522c34e
# 1    50b59cd75bed76f46522c34f
# 2    50b59cd75bed76f46522c350
# 3    50b59cd75bed76f46522c351
# ...

# %%
df.drop('_id',axis=1,inplace=True)

# %%
df
# Out:
#      student_id  class_id  Exam_score  Homework_score  Quiz_score  \
# 0             0         2       57.93           22.73       21.25
# 1             0        28       39.18           30.42       78.44
# 2             0         5       88.23           19.65       79.29
# 3             0        16       59.18            2.16       47.59
# 4             0        24        4.44            0.00       28.63
# ..          ...       ...         ...             ...         ...
# 275          48        10       19.76            6.98       88.30
# 276          48        14       66.79            0.00        6.84
# 277          48         8       87.50           45.22       77.95
# 278          48        15       17.49           24.56       26.63
# 279          49        29       26.68            0.00       43.35
#
#                            Id
# 0    50b59cd75bed76f46522c34e
# 1    50b59cd75bed76f46522c34f
# 2    50b59cd75bed76f46522c350
# 3    50b59cd75bed76f46522c351
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      280 non-null    int64
#  1   class_id        280 non-null    int64
#  2   Exam_score      280 non-null    float64
#  3   Homework_score  280 non-null    float64
#  4   Quiz_score      280 non-null    float64
#  5   Id              280 non-null    object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
clean[0]
# Out:
# [{'type': 'exam', 'score': 57.92947112575566},
#  {'type': 'quiz', 'score': 21.24542588206755},
#  {'type': 'homework', 'score': 68.1956781058743},
#  {'type': 'homework', 'score': 67.95019716560351},
#  {'type': 'homework', 'score': 18.81037253352722}]

# %%
for i in clean[0][2:]:
    print(i['score'])
# Out:
# 68.1956781058743
# 67.95019716560351
# 18.81037253352722

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [137], line 1
# ----> 1 clean[0][2:][0:]["score"]
#
# TypeError: list indices must be integers or slices, not str

# %%
df
# Out:
#      student_id  class_id  Exam_score  Homework_score  Quiz_score  \
# 0             0         2       57.93           22.73       21.25
# 1             0        28       39.18           30.42       78.44
# 2             0         5       88.23           19.65       79.29
# 3             0        16       59.18            2.16       47.59
# 4             0        24        4.44            0.00       28.63
# ..          ...       ...         ...             ...         ...
# 275          48        10       19.76            6.98       88.30
# 276          48        14       66.79            0.00        6.84
# 277          48         8       87.50           45.22       77.95
# 278          48        15       17.49           24.56       26.63
# 279          49        29       26.68            0.00       43.35
#
#                            Id
# 0    50b59cd75bed76f46522c34e
# 1    50b59cd75bed76f46522c34f
# 2    50b59cd75bed76f46522c350
# 3    50b59cd75bed76f46522c351
# ...

# %%
# Get the DataFrame column names as a list
clist = list(df.columns)

# Rearrange list the way you like 
clist_new = clist[-1:]+clist[:-1]   # brings the last column in the first place

# rPass the new list to the DataFrame - like a key list in a dict 
df = df[clist_new]
df
# Out:
#                            Id  student_id  class_id  Exam_score  \
# 0    50b59cd75bed76f46522c34e           0         2       57.93
# 1    50b59cd75bed76f46522c34f           0        28       39.18
# 2    50b59cd75bed76f46522c350           0         5       88.23
# 3    50b59cd75bed76f46522c351           0        16       59.18
# 4    50b59cd75bed76f46522c352           0        24        4.44
# ..                        ...         ...       ...         ...
# 275  50b59cd75bed76f46522c461          48        10       19.76
# 276  50b59cd75bed76f46522c462          48        14       66.79
# 277  50b59cd75bed76f46522c463          48         8       87.50
# 278  50b59cd75bed76f46522c464          48        15       17.49
# 279  50b59cd75bed76f46522c465          49        29       26.68
#
#      Homework_score  Quiz_score
# 0             22.73       21.25
# 1             30.42       78.44
# 2             19.65       79.29
# 3              2.16       47.59
# ...

# %%
df
# Out:
#                            Id  student_id  class_id  Exam_score  \
# 0    50b59cd75bed76f46522c34e           0         2       57.93
# 1    50b59cd75bed76f46522c34f           0        28       39.18
# 2    50b59cd75bed76f46522c350           0         5       88.23
# 3    50b59cd75bed76f46522c351           0        16       59.18
# 4    50b59cd75bed76f46522c352           0        24        4.44
# ..                        ...         ...       ...         ...
# 275  50b59cd75bed76f46522c461          48        10       19.76
# 276  50b59cd75bed76f46522c462          48        14       66.79
# 277  50b59cd75bed76f46522c463          48         8       87.50
# 278  50b59cd75bed76f46522c464          48        15       17.49
# 279  50b59cd75bed76f46522c465          49        29       26.68
#
#      Homework_score  Quiz_score
# 0             22.73       21.25
# 1             30.42       78.44
# 2             19.65       79.29
# 3              2.16       47.59
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              280 non-null    object
#  1   student_id      280 non-null    int64
#  2   class_id        280 non-null    int64
#  3   Exam_score      280 non-null    float64
#  4   Homework_score  280 non-null    float64
#  5   Quiz_score      280 non-null    float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
clean[100][2:]
# Out:
# [{'type': 'homework', 'score': 48.70395034065579},
#  {'type': 'homework', 'score': 60.14281257828002},
#  {'type': 'homework', 'score': 67.1876659792913},
#  {'type': 'homework', 'score': 88.01503433639428}]

# %%
clean[0]
# Out:
# [{'type': 'exam', 'score': 57.92947112575566},
#  {'type': 'quiz', 'score': 21.24542588206755},
#  {'type': 'homework', 'score': 68.1956781058743},
#  {'type': 'homework', 'score': 67.95019716560351},
#  {'type': 'homework', 'score': 18.81037253352722}]

# %%
df.drop(["Exam_score",])
# Out:
# 0      [{'type': 'exam', 'score': 57.92947112575566},...
# 1      [{'type': 'exam', 'score': 39.17749400402234},...
# 2      [{'type': 'exam', 'score': 88.22950674232497},...
# 3      [{'type': 'exam', 'score': 59.1805667559299}, ...
# 4      [{'type': 'exam', 'score': 4.444435759027499},...
#                              ...
# 275    [{'type': 'exam', 'score': 19.75901367795435},...
# 276    [{'type': 'exam', 'score': 66.79008851052096},...
# 277    [{'type': 'exam', 'score': 87.50309579619501},...
# 278    [{'type': 'exam', 'score': 17.49112864462374},...
# 279    [{'type': 'exam', 'score': 26.67878234847454},...
# Name: scores, Length: 280, dtype: object

# %%
str(clean[2][2:])
# Out:
# "[{'type': 'homework', 'score': 18.66254946562674}, {'type': 'homework', 'score': 40.28154176513361}, {'type': 'homework', 'score': 1.23735944117882}, {'type': 'homework', 'score': 88.96101200683958}]"

# %%
re.findall("\d{2}.\d+",str(clean[2][2:]))
# Out:
# ['18.66254946562674',
#  '40.28154176513361',
#  '23735944117882',
#  '88.96101200683958']

# %%
import numpy as np
avg = []
for i in range(len(clean)):
    x = re.findall("\d*.\d+",str(clean[i][2:]))
    x = list(map(float,x))
    np.array(x)
    avg.append(round(np.mean(x),2))

# %%
avg
# Out:
# [25.83,
#  24.47,
#  18.64,
#  25.56,
#  42.68,
#  28.86,
#  37.02,
#  36.59,
#  41.4,
#  24.52,
#  29.71,
#  17.34,
#  12.37,
#  40.01,
#  31.72,
#  25.0,
#  24.67,
#  39.48,
#  24.35,
#  31.32,
#  38.53,
#  13.73,
#  14.15,
#  39.81,
#  32.77,
#  28.04,
#  19.42,
#  32.06,
#  36.29,
#  31.82,
#  33.4,
#  19.44,
#  33.94,
#  24.71,
#  30.12,
#  31.07,
#  31.87,
#  17.79,
#  23.18,
#  35.5,
#  24.98,
#  32.7,
#  19.29,
#  23.68,
#  2.66,
#  20.98,
#  16.17,
#  13.23,
#  17.16,
#  21.2,
#  29.95,
#  42.06,
#  34.56,
#  18.09,
#  23.57,
#  30.83,
#  44.4,
#  16.71,
#  49.46,
#  3.56,
#  24.29,
#  29.7,
#  42.92,
#  22.86,
#  25.25,
#  17.28,
#  23.61,
#  26.39,
#  23.71,
#  23.16,
#  25.99,
#  6.8,
#  34.07,
#  25.91,
#  17.66,
#  46.12,
#  20.99,
#  35.32,
#  22.45,
#  15.73,
#  21.64,
#  46.78,
#  26.81,
#  6.98,
#  23.1,
#  9.7,
#  13.1,
#  20.23,
#  24.07,
#  21.23,
#  22.92,
#  11.21,
#  29.19,
#  43.5,
#  13.14,
#  16.58,
#  32.35,
#  16.71,
#  19.54,
#  31.79,
#  33.01,
# ...

# %%
df.drop("Homework_score",axis=1,inplace=True)

# %%
avg
# Out:
# [51.65,
#  48.94,
#  5933986029507.48,
#  16156983869120.29,
#  85.35,
#  57.72,
#  74.04,
#  73.18,
#  82.81,
#  49.05,
#  59.41,
#  34.69,
#  24.75,
#  80.02,
#  63.43,
#  50.0,
#  49.35,
#  78.95,
#  367550946733550.8,
#  62.63,
#  77.05,
#  27.45,
#  416009143855816.4,
#  79.61,
#  65.54,
#  56.07,
#  38.85,
#  64.12,
#  72.57,
#  63.64,
#  66.8,
#  38.88,
#  67.87,
#  49.42,
#  179836679483779.06,
#  62.13,
#  90463041772689.3,
#  35.59,
#  32986745399267.57,
#  71.01,
#  49.96,
#  65.41,
#  38.58,
#  47.36,
#  32775635719569.0,
#  173727194371839.28,
#  32.34,
#  53587219445159.91,
#  62357594117083.01,
#  42.41,
#  59.89,
#  84.12,
#  69.13,
#  36.18,
#  413522418045793.75,
#  61.65,
#  88.8,
#  33.42,
#  98.92,
#  611869363711897.5,
#  48.58,
#  59.41,
#  85.84,
#  45.72,
#  50.51,
#  4981926512865335.0,
#  47.23,
#  52.77,
#  47.43,
#  46.31,
#  51.99,
#  27335430437954.56,
#  68.15,
#  51.82,
#  35.32,
#  92.25,
#  15982616839613.3,
#  70.65,
#  12012480744536.77,
# ...

# %%
clean[2]
# Out:
# [{'type': 'exam', 'score': 88.22950674232497},
#  {'type': 'quiz', 'score': 79.28962650427184},
#  {'type': 'homework', 'score': 18.66254946562674},
#  {'type': 'homework', 'score': 40.28154176513361},
#  {'type': 'homework', 'score': 1.23735944117882},
#  {'type': 'homework', 'score': 88.96101200683958}]

# %%
df
# Out:
#                            Id  student_id  class_id  Exam_score  Quiz_score
# 0    50b59cd75bed76f46522c34e           0         2       57.93       21.25
# 1    50b59cd75bed76f46522c34f           0        28       39.18       78.44
# 2    50b59cd75bed76f46522c350           0         5       88.23       79.29
# 3    50b59cd75bed76f46522c351           0        16       59.18       47.59
# 4    50b59cd75bed76f46522c352           0        24        4.44       28.63
# ..                        ...         ...       ...         ...         ...
# 275  50b59cd75bed76f46522c461          48        10       19.76       88.30
# 276  50b59cd75bed76f46522c462          48        14       66.79        6.84
# 277  50b59cd75bed76f46522c463          48         8       87.50       77.95
# 278  50b59cd75bed76f46522c464          48        15       17.49       26.63
# 279  50b59cd75bed76f46522c465          49        29       26.68       43.35
#
# [280 rows x 5 columns]

# %%
data = pd.read_json('http://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/grades.json',lines=True)
data
# Out:
#                                       _id  student_id  class_id  \
# 0    {'$oid': '50b59cd75bed76f46522c34e'}           0         2
# 1    {'$oid': '50b59cd75bed76f46522c34f'}           0        28
# 2    {'$oid': '50b59cd75bed76f46522c350'}           0         5
# 3    {'$oid': '50b59cd75bed76f46522c351'}           0        16
# 4    {'$oid': '50b59cd75bed76f46522c352'}           0        24
# ..                                    ...         ...       ...
# 275  {'$oid': '50b59cd75bed76f46522c461'}          48        10
# 276  {'$oid': '50b59cd75bed76f46522c462'}          48        14
# 277  {'$oid': '50b59cd75bed76f46522c463'}          48         8
# 278  {'$oid': '50b59cd75bed76f46522c464'}          48        15
# 279  {'$oid': '50b59cd75bed76f46522c465'}          49        29
#
#                                                 scores
# 0    [{'type': 'exam', 'score': 57.92947112575566},...
# 1    [{'type': 'exam', 'score': 39.17749400402234},...
# ...

# %%
ids = [i['$oid'] for i in data["_id"]]
ids
# Out:
# ['50b59cd75bed76f46522c34e',
#  '50b59cd75bed76f46522c34f',
#  '50b59cd75bed76f46522c350',
#  '50b59cd75bed76f46522c351',
#  '50b59cd75bed76f46522c352',
#  '50b59cd75bed76f46522c353',
#  '50b59cd75bed76f46522c354',
#  '50b59cd75bed76f46522c355',
#  '50b59cd75bed76f46522c356',
#  '50b59cd75bed76f46522c357',
#  '50b59cd75bed76f46522c358',
#  '50b59cd75bed76f46522c359',
#  '50b59cd75bed76f46522c35a',
#  '50b59cd75bed76f46522c35b',
#  '50b59cd75bed76f46522c35c',
#  '50b59cd75bed76f46522c35d',
#  '50b59cd75bed76f46522c35e',
#  '50b59cd75bed76f46522c35f',
#  '50b59cd75bed76f46522c360',
#  '50b59cd75bed76f46522c361',
#  '50b59cd75bed76f46522c362',
#  '50b59cd75bed76f46522c363',
#  '50b59cd75bed76f46522c364',
#  '50b59cd75bed76f46522c365',
#  '50b59cd75bed76f46522c366',
#  '50b59cd75bed76f46522c367',
#  '50b59cd75bed76f46522c368',
#  '50b59cd75bed76f46522c369',
#  '50b59cd75bed76f46522c36a',
#  '50b59cd75bed76f46522c36b',
#  '50b59cd75bed76f46522c36c',
#  '50b59cd75bed76f46522c36d',
# ...

# %%
clean = [i for i in data['scores']]
for i in data['scores']:
    print(i)
# Out:
# [{'type': 'exam', 'score': 57.92947112575566}, {'type': 'quiz', 'score': 21.24542588206755}, {'type': 'homework', 'score': 68.1956781058743}, {'type': 'homework', 'score': 67.95019716560351}, {'type': 'homework', 'score': 18.81037253352722}]
# [{'type': 'exam', 'score': 39.17749400402234}, {'type': 'quiz', 'score': 78.44172815491468}, {'type': 'homework', 'score': 20.81782269075502}, {'type': 'homework', 'score': 70.44520452408949}, {'type': 'homework', 'score': 50.66616327819226}, {'type': 'homework', 'score': 53.84983118363991}]
# [{'type': 'exam', 'score': 88.22950674232497}, {'type': 'quiz', 'score': 79.28962650427184}, {'type': 'homework', 'score': 18.66254946562674}, {'type': 'homework', 'score': 40.28154176513361}, {'type': 'homework', 'score': 1.23735944117882}, {'type': 'homework', 'score': 88.96101200683958}]
# ...

# %%
clean[0]
# Out:
# [{'type': 'exam', 'score': 57.92947112575566},
#  {'type': 'quiz', 'score': 21.24542588206755},
#  {'type': 'homework', 'score': 68.1956781058743},
#  {'type': 'homework', 'score': 67.95019716560351},
#  {'type': 'homework', 'score': 18.81037253352722}]

# %%
exam = [i[0]['score'] for i in clean]
quiz = [i[1]['score'] for i in clean]

# %%
clean[0]
# Out:
# [{'type': 'exam', 'score': 57.92947112575566},
#  {'type': 'quiz', 'score': 21.24542588206755},
#  {'type': 'homework', 'score': 68.1956781058743},
#  {'type': 'homework', 'score': 67.95019716560351},
#  {'type': 'homework', 'score': 18.81037253352722}]

# %%
for i in range(1):
    count = 0
    for val in range(2,len(i)):
        print(val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [226], line 3
#       1 for i in range(1):
#       2     count = 0
# ----> 3     for val in range(2,len(i)):
#       4         print(val)
#
# TypeError: object of type 'int' has no len()

# %%
clean[0][2]['type'] == 'homework'
# Out:
# True
